# %% [markdown]
# # Week 1 Assignment: **Jupyter** **Notebooks** **+** **Github**

# %% [markdown]
# https://github.com/jaynuel/AIM-5001/blob/master/README.md
#
# - **Dataset** **Original** **location:** https://data.fivethirtyeight.com/
#
# - **Local** **Computer** **Location:** <font color=blue>C:\Users\PC\Desktop\election-forecasts-2020 (1).zip\election-forecasts-2020</font>

# %% [markdown]
# # What isterests me about this dataset?
#
# **2020** has been a different year, to say the least. The whole world has
# experienced a novel pandemic, the devastating effects of natural disasters,
# social unrests and historic international peace aggrements. In the mist of this unprecendented
# context, the United States of America prepares to cast a vote on November to elect its
# Commander-in-Chief.
#
# The dataset I chose intended to forecast the results of the upcoming USA elections. I
# am interested in learning how this forecast compares to the actual election's
# results. I am also interested in understanding the difference, if any, between the counts of
# the sample surveyed and that of the actual voters.
#
# Will the final election results be within the margin of error that polls show? Could the margin
# of error be decreased by removing some variables in the analysis and if so, what does
# that tell us? Can we learn something about polls for future elections?
#
# Those are some of the questions I would like to be asking and answering by analyzing this
# dataset.

# %% [markdown]
# ![0628_LatestPOLLS-16x9_F1.png](attachment:0628_LatestPOLLS-16x9_F1.png)
