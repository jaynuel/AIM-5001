# %%
import numpy as np
import csv
#with open(r'C:\Users\PC\Desktop\Data Acquisition & Management\HW\1\car/cars-sample35.txt') as csvfile:
 #readCSV = csv.reader(csvfile)
 #for row in readCSV:
     #print(row)  
     #break 
 
#my_array=np.array(readCSV)
#for x in range(33):    
    #price[x]=np.my_arrayreadCSV[x][0]

# %%
#Answer to question 1 


print("\033[1m" +'Answer to question 1:'"\033[0m")
print('')


masterlist=[['high', 'high', '2', '4', 'med', 'low', 'unacc'],
['high', 'high', '4', 'more', 'small', 'high', 'acc'],
['high', 'high', '4', 'more', 'big', 'low', 'unacc'],
['high', 'low', '2', 'more', 'big', 'high', 'acc'],
['vhigh', 'low', '3', '2', 'med', 'med', 'unacc'],
['low', 'high', '2', '2', 'small', 'low', 'unacc'],
['med', 'med', '4', 'more', 'med', 'high', 'vgood'],
['low', 'low', '3', '2', 'big', 'med', 'unacc'],
['vhigh', 'low', '2', '2', 'small', 'low', 'unacc'],
['vhigh', 'high', '4', '4', 'med', 'low', 'unacc'],
['low', 'low', '2', '2', 'med', 'med', 'unacc'],
['vhigh', 'low', '4', 'more', 'small', 'high', 'acc'],
['high', 'low', '2', '4', 'big', 'med', 'acc'],
['low', 'vhigh', '3', 'more', 'big', 'low', 'unacc'],
['high', 'low', '5more', '2', 'big', 'med', 'unacc'],
['vhigh', 'high', '2', 'more', 'med', 'high', 'unacc'],
['med', 'med', '2', '2', 'small', 'low', 'unacc'],
['high', 'low', '5more', '4', 'med', 'high', 'acc'],
['low', 'low', '3', 'more', 'med', 'high', 'vgood'],
['low', 'low', '2', '2', 'big', 'med', 'unacc'],
['med', 'high', '4', '2', 'big', 'high', 'unacc'],
['low', 'low', '2', '2', 'small', 'high', 'unacc'],
['vhigh', 'high', '5more', '4', 'med', 'med', 'unacc'],
['med', 'vhigh', '2', '2', 'big', 'low', 'unacc'],
['low', 'vhigh', '4', '4', 'big', 'low', 'unacc'],
['vhigh', 'low', '3', 'more', 'big', 'low', 'unacc'],
['med', 'vhigh', '3', '4', 'small', 'low', 'unacc'],
['high', 'high', '3', '4', 'med', 'med', 'unacc'],
['low', 'high', '5more', '2', 'big', 'low', 'unacc'],
['med', 'high', '5more', '2', 'med', 'med', 'unacc'],
['high', 'low', '3', '4', 'med', 'high', 'acc'],
['high', 'vhigh', '5more', '4', 'med', 'med', 'unacc'],
['low', 'low', '5more', '2', 'med', 'low', 'unacc'],
['vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'],
['high', 'low', '3', '2', 'big', 'high', 'unacc']]

#I created a list for each category

price=[]
maint_cost=[]
num_door=[]
num_pass=[]
luggage=[]
safety=[]
vehicle=[]

#I added the location of each vector in the masterlist:

for x in range(len(masterlist)):
    price.append(masterlist[x][-7])
    maint_cost.append(masterlist[x][-6])
    num_door.append(masterlist[x][-5])
    num_pass.append(masterlist[x][-4])
    luggage.append(masterlist[x][-3])
    safety.append(masterlist[x][-2])
    vehicle.append(masterlist[x][-1])

print("\033[1m"'Price'"\033[0m")
print(price)
print('')
print("\033[1m"'Maintenance cost'"\033[0m")
print(maint_cost)
print('')
print("\033[1m"'Number of doors'"\033[0m")
print(num_door)
print('')
print("\033[1m"'Number of passengers'"\033[0m")
print(num_pass)
print('')
print("\033[1m"'Luggage capacity'"\033[0m")
print(luggage)
print('')
print("\033[1m"'Safety rating'"\033[0m")
print(safety)
print('')
print("\033[1m"'Classification of vehicle'"\033[0m")
print(vehicle)
print('')

#----------------------------------------------------------------------------------------------------------------------

print("\033[1m"'Answer to question 2:'"\033[0m")


#Answer question 2
priceindex=[i for i in range(len(price)) if price[i]== 'med']
print("\033[1m"'-Indexes of all "med" prices in the list are: '"\033[0m", priceindex)
print('')

#----------------------------------------------------------------------------------------------------------------------

print("\033[1m"'Answer to question 3:'"\033[0m")


#Answer to question 3
#I reference this link to access element in a list of indexes
#https://www.geeksforgeeks.org/python-accessing-all-elements-at-given-list-of-indexes/

num_pass1=[num_pass[i] for i in priceindex]
print("\033[1m"'-The number of passangers for autos with a "med" price are: '"\033[0m" + str(num_pass1))
print('')
#----------------------------------------------------------------------------------------------------------------------

print("\033[1m"'Answer to question 4:'"\033[0m")


#Answer question 4
autoindex=[p for p in range(len(price)) if price[p]== 'high' and range(len(maint_cost)) if maint_cost[p]!= 'low']
print("\033[1m"'-Indexes of all cars with a "high" price and not a "low" maintenance cost are: '"\033[0m", autoindex)
print('')

#----------------------------------------------------------------------------------------------------------------------

print("\033[1m"'Answer to question 5:'"\033[0m")


#Answer question 5
twodoors=[d for d in range(len(num_door)) if num_door[d]== '2' and range(len(luggage)) if luggage[d]== 'big']
print("\033[1m"'-Indexes for autos having "2" doors and a luggage value of "big": '"\033[0m", twodoors)
print('')

#----------------------------------------------------------------------------------------------------------------------

print("\033[1m"'Answer to question 6:'"\033[0m")

print("\033[1m"'-The average number of doors across all 35 autos is:'"\033[0m")
#Answer to question 6  
# To replace '5more' to '5' I referenced the link below: 
#https://www.geeksforgeeks.org/python-replace-substring-in-list-of-strings/ 

replace=[sub.replace('5more', '5') for sub in num_door]

# Change the list from str to int:
for i in range(len(replace)):
    replace[i]=int(replace[i])

#I referenced this youtube tutorial to write the avg function: https://www.youtube.com/watch?v=2Ej3HR4r8l4&t=306s
def avg(total):
    to= 0
    for f in total:
        to=to + f
    totalavg=to/len(total)
    return totalavg

print(avg(replace))
# Out:
# Answer to question 1:
#
# Price
# ['high', 'high', 'high', 'high', 'vhigh', 'low', 'med', 'low', 'vhigh', 'vhigh', 'low', 'vhigh', 'high', 'low', 'high', 'vhigh', 'med', 'high', 'low', 'low', 'med', 'low', 'vhigh', 'med', 'low', 'vhigh', 'med', 'high', 'low', 'med', 'high', 'high', 'low', 'vhigh', 'high']
#
# Maintenance cost
# ['high', 'high', 'high', 'low', 'low', 'high', 'med', 'low', 'low', 'high', 'low', 'low', 'low', 'vhigh', 'low', 'high', 'med', 'low', 'low', 'low', 'high', 'low', 'high', 'vhigh', 'vhigh', 'low', 'vhigh', 'high', 'high', 'high', 'low', 'vhigh', 'low', 'vhigh', 'low']
#
# Number of doors
# ['2', '4', '4', '2', '3', '2', '4', '3', '2', '4', '2', '4', '2', '3', '5more', '2', '2', '5more', '3', '2', '4', '2', '5more', '2', '4', '3', '3', '3', '5more', '5more', '3', '5more', '5more', '4', '3']
#
# Number of passengers
# ...
